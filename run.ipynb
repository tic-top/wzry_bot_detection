# %%
import requests
import json

class HonorOfKingsAPI:
    def __init__(self, camptoken, deviceid, encodeparam):
        self.base_url = "https://api-camp.honorofkings.com/game/battledetail"
        self.headers = {
            "accept": "application/json, text/plain, */*",
            "accept-language": "zh-CN,zh;q=0.9,en;q=0.8",
            "camp-language": "zh-CN",
            "camp-region": "840",
            "campsource": "HOK-CAMP",
            "camptoken": camptoken,
            "content-type": "application/json",
            "deviceid": deviceid,
            "encodeparam": encodeparam,
            "gameid": "29134",
            "origin": "https://camp.honorofkings.com",
            "referer": "https://camp.honorofkings.com/",
            "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36"
        }

    def get_battle_detail(self, game_seq, game_svr, open_id, relay_svr, target_role_id, battle_type=15):
        """
        获取对局详情
        
        参数:
            game_seq (str): 游戏序列号
            game_svr (str): 游戏服务器
            open_id (str): 玩家ID
            relay_svr (str): 中继服务器
            target_role_id (str): 目标角色ID
            battle_type (int): 对局类型,默认15
        """
        payload = {
            "battleType": battle_type,
            "gameSeq": game_seq,
            "gameSvr": game_svr,
            "openId": open_id,
            "relaySvr": relay_svr,
            "targetRoleId": target_role_id
        }
        
        try:
            response = requests.post(self.base_url, headers=self.headers, json=payload)
            response.raise_for_status()
            return response.json()
        except requests.exceptions.RequestException as e:
            print(f"请求出错: {e}")
            return None

def main():
    # 初始化API(这些值需要从你的实际session中获取)
    api = HonorOfKingsAPI(
        camptoken="ki33zdrwy2qqr8ogftybtzt7r1zhh0yz",
        deviceid="HEiNhQJzndEsEXAXDNAH030xSieWSat3",
        encodeparam="U2U5knbCWEj2XZqKiCa8Y1UU0HWM95Z79847SU1E2+u83HPoJ6/PUf7pa42l/kmVAnn488k/zSGHIk6a1WUyhmWtpXe28NA2SWOz8WPuoJAVe/fOmEf3ysYPuXoIm2fEbRkPvQ9OiluSJIU7"
    )
    
    # 获取对局详情示例
    result = api.get_battle_detail(
        game_seq="1729393370",
        game_svr="112880",
        open_id="1660150296936322642",
        relay_svr="1796736536",
        target_role_id="2700755"
    )
    
    # 打印结果
    if result:
        print(json.dumps(result, indent=2, ensure_ascii=False))
    else:
        print("获取对局详情失败")

if __name__ == "__main__":
    main()
# Out:
# 请求出错: 403 Client Error: Forbidden for url: https://api-camp.honorofkings.com/game/battledetail
# 获取对局详情失败

# %%
import requests
import json

def get_battle_detail():
    # API endpoint
    url = "https://api-camp.honorofkings.com/game/battledetail"
    
    # Request headers
    headers = {
        "accept": "application/json, text/plain, */*",
        "accept-language": "zh-CN,zh;q=0.9,en;q=0.8",
        "camp-language": "zh-CN",
        "camp-region": "840",
        "campsource": "HOK-CAMP",
        "camptoken": "ki33zdrwy2qqr8ogftybtzt7r1zhh0yz",
        "content-type": "application/json",
        "deviceid": "HEiNhQJzndEsEXAXDNAH030xSieWSat3",
        "encodeparam": "U2U5knbCWEj2XZqKiCa8Y1UU0HWM95Z79847SU1E2+u83HPoJ6/PUf7pa42l/kmVAnn488k/zSGHIk6a1WUyhmWtpXe28NA2SWOz8WPuoJAVe/fOmEf3ysYPuXoIm2fEbRkPvQ9OiluSJIU7",
        "gameid": "29134",
        "gameopenid": "1660150296936322642",
        "origin": "https://camp.honorofkings.com",
        "referer": "https://camp.honorofkings.com/",
        "user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36"
    }
    
    # Request payload
    payload = {
        "battleType": 15,
        "gameSeq": "1729393370",
        "gameSvr": "112880",
        "openId": "1660150296936322642",
        "relaySvr": "1796736536",
        "targetRoleId": "2700755"
    }
    
    try:
        # Make POST request
        response = requests.post(url, headers=headers, json=payload)
        
        # Check if request was successful
        response.raise_for_status()
        
        # Return JSON response
        return response.json()
        
    except requests.exceptions.RequestException as e:
        print(f"Error making request: {e}")
        return None

def main():
    # Get battle details
    result = get_battle_detail()
    
    # Print results
    if result:
        print(json.dumps(result, indent=2, ensure_ascii=False))
    else:
        print("Failed to get battle details")

if __name__ == "__main__":
    main()
# Out:
# Error making request: 403 Client Error: Forbidden for url: https://api-camp.honorofkings.com/game/battledetail
# Failed to get battle details
